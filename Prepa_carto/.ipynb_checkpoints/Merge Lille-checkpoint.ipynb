# %%
import pandas as pd

# %%
lille_folium = pd.read_csv('lille_folium.csv', dtype={'CODGEO': 'string'})

# %%
lille_folium.dtypes
# Out:
# REG           int64
# DEP           int64
# CODGEO       string
# LIBGEO       object
# AAV20         int64
# LIBAAV2      object
# CATEAAV       int64
# LIBCATE      object
# TAAV20        int64
# LIBTAAV      object
# geometry     object
# TP6020      float64
# dtype: object

# %%
lille_folium.head()
# Out:
#    REG  DEP CODGEO               LIBGEO  AAV20                   LIBAAV2  \
# 0   32   59  59004        Aix-en-Pévèle      4  Lille (partie française)
# 1   32   59  59005  Allennes-les-Marais      4  Lille (partie française)
# 2   32   59  59009    Villeneuve-d'Ascq      4  Lille (partie française)
# 3   32   59  59011           Annoeullin      4  Lille (partie française)
# 4   32   59  59013             Anstaing      4  Lille (partie française)
#
#    CATEAAV                          LIBCATE  TAAV20  \
# 0       20           Commune de la couronne       4
# 1       20           Commune de la couronne       4
# 2       12  Autre commune du pôle principal       4
# 3       20           Commune de la couronne       4
# 4       20           Commune de la couronne       4
#
#                                           LIBTAAV  \
# 0  Aire de 700 000 habitants ou plus (hors Paris)
# 1  Aire de 700 000 habitants ou plus (hors Paris)
# 2  Aire de 700 000 habitants ou plus (hors Paris)
# 3  Aire de 700 000 habitants ou plus (hors Paris)
# 4  Aire de 700 000 habitants ou plus (hors Paris)
#
#                                             geometry  TP6020
# 0  POLYGON ((3.30066713038037 50.48727603709588, ...     NaN
# 1  POLYGON ((2.9632207383121996 50.52788369731953...     NaN
# 2  POLYGON ((3.1379398906166807 50.60120290774355...    20.0
# 3  POLYGON ((2.9268652613093193 50.50780704062396...    10.0
# 4  POLYGON ((3.1921439736945003 50.59329505025182...     NaN

# %%
lille_folium = lille_folium.drop('TP6020', axis=1)

# %%
data_lille = pd.read_csv('data_lille.csv', dtype={'CODGEO': 'string'})

# %%
data_lille.head()
# Out:
#   CODGEO  Taux_chomage  taux_sans_diplome  taux_maison_princ  taux_loc_princ  \
# 0  01004         14.77              19.36              42.45           52.76
# 1  01007          7.61              13.33              84.69           24.29
# 2  01014         13.98              32.39              65.78           34.89
# 3  01025          7.14              18.07              95.18           13.92
# 4  01031         14.99              31.01              35.29           58.31
#
#    taux_inactifs  salaire_ouvrier  salaire_employe  TP6020
# 0          14.99        11.772666        11.259209    17.0
# 1          12.18        12.520221        11.917058     7.0
# 2          16.51        11.848787        12.175141    10.0
# 3          12.42        12.400297        11.663794     6.0
# 4          17.40        11.759778        11.474574    19.0

# %%
data_lille.head()
# Out:
#   CODGEO  Taux_chomage  taux_sans_diplome  taux_maison_princ  taux_loc_princ  \
# 0  01004         14.77              19.36              42.45           52.76
# 1  01007          7.61              13.33              84.69           24.29
# 2  01014         13.98              32.39              65.78           34.89
# 3  01025          7.14              18.07              95.18           13.92
# 4  01031         14.99              31.01              35.29           58.31
#
#    taux_inactifs  salaire_ouvrier  salaire_employe  TP6020
# 0          14.99        11.772666        11.259209    17.0
# 1          12.18        12.520221        11.917058     7.0
# 2          16.51        11.848787        12.175141    10.0
# 3          12.42        12.400297        11.663794     6.0
# 4          17.40        11.759778        11.474574    19.0

# %%
lille_all_data = lille_folium.merge(data_lille, on='CODGEO', how='left')

# %%
lille_folium.shape
# Out:
# (201, 11)

# %%
lille_all_data.shape
# Out:
# (201, 19)

# %%
lille_all_data.to_csv('../lille_all_data.csv', index=False)

# %%
lille_all_data.head()
# Out:
#    REG  DEP CODGEO               LIBGEO  AAV20                   LIBAAV2  \
# 0   32   59  59004        Aix-en-Pévèle      4  Lille (partie française)
# 1   32   59  59005  Allennes-les-Marais      4  Lille (partie française)
# 2   32   59  59009    Villeneuve-d'Ascq      4  Lille (partie française)
# 3   32   59  59011           Annoeullin      4  Lille (partie française)
# 4   32   59  59013             Anstaing      4  Lille (partie française)
#
#    CATEAAV                          LIBCATE  TAAV20  \
# 0       20           Commune de la couronne       4
# 1       20           Commune de la couronne       4
# 2       12  Autre commune du pôle principal       4
# 3       20           Commune de la couronne       4
# 4       20           Commune de la couronne       4
#
#                                           LIBTAAV  \
# 0  Aire de 700 000 habitants ou plus (hors Paris)
# 1  Aire de 700 000 habitants ou plus (hors Paris)
# 2  Aire de 700 000 habitants ou plus (hors Paris)
# 3  Aire de 700 000 habitants ou plus (hors Paris)
# 4  Aire de 700 000 habitants ou plus (hors Paris)
#
#                                             geometry  Taux_chomage  \
# 0  POLYGON ((3.30066713038037 50.48727603709588, ...           NaN
# 1  POLYGON ((2.9632207383121996 50.52788369731953...           NaN
# 2  POLYGON ((3.1379398906166807 50.60120290774355...         17.85
# 3  POLYGON ((2.9268652613093193 50.50780704062396...         12.51
# 4  POLYGON ((3.1921439736945003 50.59329505025182...           NaN
#
#    taux_sans_diplome  taux_maison_princ  taux_loc_princ  taux_inactifs  \
# 0                NaN                NaN             NaN            NaN
# 1                NaN                NaN             NaN            NaN
# 2              13.98              42.15           51.94          23.66
# 3              23.71              77.71           25.82          21.22
# 4                NaN                NaN             NaN            NaN
#
#    salaire_ouvrier  salaire_employe  TP6020
# 0              NaN              NaN     NaN
# 1              NaN              NaN     NaN
# 2        10.900231        11.269702    20.0
# 3        11.395098        11.778428    10.0
# 4              NaN              NaN     NaN
