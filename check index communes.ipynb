# %%
import pandas as pd

# %%
lille = pd.read_csv('lille_all_data.csv')
communes = lille[lille.TP6020.isna() == False].sort_values(by='LIBGEO', ascending=True)[['LIBGEO']].reset_index(drop=True)

# %%
pd.set_option('display.max_rows', None)

# %%
communes
# Out:
#                        LIBGEO
# 0                  Annoeullin
# 1                 Armentières
# 2             Auchy-les-Mines
# 3                    Bailleul
# 4                    Baisieux
# 5                      Bauvin
# 6               Billy-Berclau
# 7                     Bondues
# 8                  Bousbecque
# 9                      Carvin
# 10                    Comines
# 11        Courcelles-lès-Lens
# 12                  Coutiches
# 13                      Croix
# 14                    Cysoing
# 15                    Douvrin
# 16             Erquinghem-Lys
# 17                   Estaires
# 18           Faches-Thumesnil
# 19                     Fenain
# 20          Flines-lez-Raches
# 21                     Fretin
# 22             Godewaersvelde
# 23                 Gondecourt
# 24                    Haisnes
# 25   Hallennes-lez-Haubourdin
# 26                    Halluin
# 27                 Haubourdin
# 28                        Hem
# 29           Houplin-Ancoisne
# ...
